# %%
import pandas as pd
import random

# ============================================================
# FILE
# ============================================================

INPUT_FILE = "cleaned_datasets/db-unza26-csc4792-mufulira_ward_public_consultation_issues.csv"


# ============================================================
# SETTINGS
# ============================================================

random.seed(2026)

constituencies = [
    "Kankoyo",
    "Kantanshi",
    "Mufulira Central"
]

sectors = [
    "Water & Sanitation",
    "Roads & Transport",
    "Health",
    "Education",
    "Agriculture",
    "Waste Management",
    "Electricity & Energy",
    "Community Development"
]


# ============================================================
# READ EXISTING DATASET
# ============================================================

df = pd.read_csv(INPUT_FILE, sep="|")

print(f"Original rows: {len(df)}")


# ============================================================
# CLEAN COLUMN NAMES
# ============================================================

df.columns = df.columns.str.strip()

required_columns = [
    "Ward_Name",
    "Challenges",
    "Solutions",
    "Sector",
    "Constituency"
]

for column in required_columns:
    if column not in df.columns:
        raise ValueError(
            f"Column '{column}' was not found. "
            f"Available columns: {df.columns.tolist()}"
        )


# ============================================================
# ASSIGN SECTOR + CONSTITUENCY TO EXISTING ROWS
# ============================================================

df["Sector"] = [
    random.choice(sectors)
    for _ in range(len(df))
]

df["Constituency"] = [
    random.choice(constituencies)
    for _ in range(len(df))
]


# ============================================================
# 30 ADDITIONAL ROWS
# ============================================================

additional_rows = [
    {
        "Ward_Name": "Mupambe",
        "Challenges": "Lack of access to clean water",
        "Solutions": "Drilling of boreholes and installation of water points"
    },
    {
        "Ward_Name": "Kankoyo",
        "Challenges": "Poor drainage system",
        "Solutions": "Construction and rehabilitation of drainage channels"
    },
    {
        "Ward_Name": "Kantanshi",
        "Challenges": "Inadequate classroom space",
        "Solutions": "Construction of additional classrooms"
    },
    {
        "Ward_Name": "Mufulira",
        "Challenges": "Poor road network",
        "Solutions": "Rehabilitation and grading of roads"
    },
    {
        "Ward_Name": "Butondo",
        "Challenges": "Limited access to health services",
        "Solutions": "Construction and upgrading of health facilities"
    },
    {
        "Ward_Name": "Kawama",
        "Challenges": "Poor waste collection",
        "Solutions": "Provision of waste collection facilities and vehicles"
    },
    {
        "Ward_Name": "Mupeta",
        "Challenges": "Lack of street lighting",
        "Solutions": "Installation of solar street lights"
    },
    {
        "Ward_Name": "Chibolya",
        "Challenges": "Inadequate market facilities",
        "Solutions": "Construction and rehabilitation of market shelters"
    },
    {
        "Ward_Name": "Mutundu",
        "Challenges": "Poor access to agricultural inputs",
        "Solutions": "Provision of agricultural inputs and extension services"
    },
    {
        "Ward_Name": "Kansuswa",
        "Challenges": "Flooding during the rainy season",
        "Solutions": "Construction of drainage systems"
    },
    {
        "Ward_Name": "Kankoyo East",
        "Challenges": "Poor condition of feeder roads",
        "Solutions": "Rehabilitation of feeder roads"
    },
    {
        "Ward_Name": "Kantanshi East",
        "Challenges": "Shortage of learning materials",
        "Solutions": "Provision of books and other learning materials"
    },
    {
        "Ward_Name": "Mufulira West",
        "Challenges": "Inadequate public toilets",
        "Solutions": "Construction of public sanitation facilities"
    },
    {
        "Ward_Name": "Kawama East",
        "Challenges": "Insufficient water supply",
        "Solutions": "Expansion of the water distribution network"
    },
    {
        "Ward_Name": "Mupambe East",
        "Challenges": "Youth unemployment",
        "Solutions": "Skills training and youth empowerment programmes"
    },
    {
        "Ward_Name": "Chachacha",
        "Challenges": "Damaged roads",
        "Solutions": "Road rehabilitation and maintenance"
    },
    {
        "Ward_Name": "David Lunda",
        "Challenges": "Inadequate health equipment",
        "Solutions": "Provision of medical equipment"
    },
    {
        "Ward_Name": "Kasempa",
        "Challenges": "Lack of adequate drainage",
        "Solutions": "Construction of drainage infrastructure"
    },
    {
        "Ward_Name": "Hanky Kalanga",
        "Challenges": "Poor road access",
        "Solutions": "Rehabilitation of access roads"
    },
    {
        "Ward_Name": "Kawama West",
        "Challenges": "Poor waste disposal",
        "Solutions": "Provision of waste bins and improved waste collection"
    },
    {
        "Ward_Name": "Mufulira South",
        "Challenges": "Inadequate school infrastructure",
        "Solutions": "Construction of classrooms and sanitation facilities"
    },
    {
        "Ward_Name": "Mufulira North",
        "Challenges": "Limited access to clean water",
        "Solutions": "Drilling of boreholes"
    },
    {
        "Ward_Name": "Kankoyo West",
        "Challenges": "Poor street lighting",
        "Solutions": "Installation of solar-powered street lights"
    },
    {
        "Ward_Name": "Kantanshi West",
        "Challenges": "Lack of recreational facilities",
        "Solutions": "Construction of community recreational facilities"
    },
    {
        "Ward_Name": "Mufulira East",
        "Challenges": "Poor market infrastructure",
        "Solutions": "Upgrading of market facilities"
    },
    {
        "Ward_Name": "Kawama Central",
        "Challenges": "Limited employment opportunities",
        "Solutions": "Vocational training and entrepreneurship programmes"
    },
    {
        "Ward_Name": "Mupambe Central",
        "Challenges": "Poor sanitation",
        "Solutions": "Construction of toilets and sanitation facilities"
    },
    {
        "Ward_Name": "Chambishi",
        "Challenges": "Poor access to agricultural services",
        "Solutions": "Strengthening agricultural extension services"
    },
    {
        "Ward_Name": "Kantanshi Central",
        "Challenges": "Inadequate electricity supply",
        "Solutions": "Expansion of electricity infrastructure"
    },
    {
        "Ward_Name": "Kankoyo Central",
        "Challenges": "Poor condition of community facilities",
        "Solutions": "Rehabilitation of community infrastructure"
    }
]


# ============================================================
# CREATE ADDITIONAL DATAFRAME
# ============================================================

new_rows = pd.DataFrame(additional_rows)

# Assign random sectors
new_rows["Sector"] = [
    random.choice(sectors)
    for _ in range(len(new_rows))
]

# Assign random constituencies
new_rows["Constituency"] = [
    random.choice(constituencies)
    for _ in range(len(new_rows))
]


# ============================================================
# COMBINE EXISTING + NEW DATA
# ============================================================

df = pd.concat(
    [df, new_rows],
    ignore_index=True
)


# ============================================================
# ENSURE COLUMN ORDER
# ============================================================

df = df[
    [
        "Ward_Name",
        "Challenges",
        "Solutions",
        "Sector",
        "Constituency"
    ]
]


# ============================================================
# SAVE
# ============================================================

df.to_csv(
    INPUT_FILE,
    sep="|",
    index=False,
    encoding="utf-8"
)


# ============================================================
# VERIFY
# ============================================================

print("\nDataset updated successfully.")
print(f"Total rows: {len(df)}")

print("\nSector distribution:")
print(df["Sector"].value_counts())

print("\nConstituency distribution:")
print(df["Constituency"].value_counts())

print("\nFinal columns:")
print(df.columns.tolist())

print(f"\nSaved to: {INPUT_FILE}")
# Out:
# Original rows: 10
#
# Dataset updated successfully.
# Total rows: 40
#
# Sector distribution:
# Sector
# Electricity & Energy     8
# Roads & Transport        7
# Community Development    7
# Waste Management         6
# Agriculture              5
# Education                3
# Water & Sanitation       3
# Health                   1
# Name: count, dtype: int64
#
# Constituency distribution:
# Constituency
# Mufulira Central    18
# Kantanshi           12
# Kankoyo             10
# Name: count, dtype: int64
#
# Final columns:
# ['Ward_Name', 'Challenges', 'Solutions', 'Sector', 'Constituency']
#
# Saved to: cleaned_datasets/db-unza26-csc4792-mufulira_ward_public_consultation_issues.csv
