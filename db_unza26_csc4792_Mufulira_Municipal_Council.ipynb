# %% [markdown]
# <a href="https://colab.research.google.com/github/Mambwe-LC/db-unza26-csc4792-Mufulira-Municipal-Council-group-8/blob/main/db_unza26_csc4792_Mufulira_Municipal_Council.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv("scrapping/cdf_dataset_scrapping/db-unza26-csc4792-mufulira_cdf_skills_applicants.csv", sep="|")

data.tail()
# Out:
#          Constituency   No Ward  \
# 219  Mufulira Central  480  NaN
# 220  Mufulira Central  481  NaN
# 221  Mufulira Central  482  NaN
# 222  Mufulira Central  483  NaN
# 223  Mufulira Central  484  NaN
#
#                                          Name_of_Pupil          NRC Gender  \
# 219  |MUTUNDU Chona Kelvin |Single Driving Course |...  357554/33/1    NaN
# 220  |MUTUNDU Kasongo Single Driving Course |C 30 D...  398957/66/1    NaN
# 221  |MUTUNDU CHANDA 01.04.97 SINGLE DRIVING C CERT...  382813/33/1    NaN
# 222  |MUTUNDU BWALYA 15.03.02 SINGLE DRIVING C CERT...  357213/33/1    NaN
# 223  | MUTUNDU PETER MWAPE | FINANCIAL |DRIVING C C...  354957/66/1    NaN
#
#     Date_of_Birth  Type_of_Vulnerability  Study_Programme  Study_Type  \
# 219    17/02/1998                    NaN              NaN         NaN
# 220      4/8/2002                    NaN              NaN         NaN
# 221           NaN                    NaN              NaN         NaN
# 222           NaN                    NaN              NaN         NaN
# 223      6/5/1998                    NaN              NaN         NaN
#
#      Course_Duration  Name_of_Skills_Institution  Total  Guardian_Parent_Name  \
# 219              NaN                         NaN    NaN                   NaN
# 220              NaN                         NaN    NaN                   NaN
# 221              NaN                         NaN    NaN                   NaN
# 222              NaN                         NaN    NaN                   NaN
# 223              NaN                         NaN    NaN                   NaN
#
#                                        Source_File
# 219  2025-Mufulira-Central-Skills-CDF-Approved.pdf
# 220  2025-Mufulira-Central-Skills-CDF-Approved.pdf
# 221  2025-Mufulira-Central-Skills-CDF-Approved.pdf
# 222  2025-Mufulira-Central-Skills-CDF-Approved.pdf
# 223  2025-Mufulira-Central-Skills-CDF-Approved.pdf
